# %% [markdown]
# <a href="https://colab.research.google.com/github/delademf/object_detection_for_casting_process/blob/main/object_detection_in_casting_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
import ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.0/722.0 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 45.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 54.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 73.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 828.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.7 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model='yolov8n.pt' source ='/content/Melting Artillery Bands into Anvil - Bronze Casting.mp4'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 26.9MB/s]
# Ultralytics YOLOv8.1.30 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/1762) /content/Melting Artillery Bands into Anvil - Bronze Casting.mp4: 640x384 (no detections), 253.0ms
# video 1/1 (frame 2/1762) /content/Melting Artillery Bands into Anvil - Bronze Casting.mp4: 640x384 (no detections), 151.5ms
# video 1/1 (frame 3/1762) /content/Melting Artillery Bands into Anvil - Bronze Casting.mp4: 640x384 (no detections), 159.8ms
# video 1/1 (frame 4/1762) /content/Melting Artillery Bands into Anvil - Bronze Casting.mp4: 640x384 (no detections), 156.6ms
# video 1/1 (frame 5/1762) /content/Melting Artillery Bands into Anvil - Bronze Casting.mp4: 640x384 1 skis, 1 baseball bat, 140.4ms
# video 1/1 (frame 6/1762) /content/Melting Artillery Bands into Anvil - Bronze Casting.mp4: 640x384 (no detections), 140.1ms
# ...

# %%
# !yolo predict model='/content/WhatsApp Image 2024-03-20 at 19.50.54_2f4db7fb.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 72.4MB/s]
# Ultralytics YOLOv8.1.30 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (AMD EPYC 7B12)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/WhatsApp Image 2024-03-20 at 19.50.54_2f4db7fb.jpg: 384x640 1 person, 1 pizza, 194.8ms
# Speed: 12.7ms preprocess, 194.8ms inference, 22.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco128.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('/content/Melting Artillery Bands into Anvil - Bronze Casting.mp4')  # predict on an image
results = model.export(format='onnx')  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.1.30 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (AMD EPYC 7B12)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('/content/WhatsApp Image 2024-03-20 at 19.50.54_2f4db7fb.jpg')  # predict on an image
# Out:
# Ultralytics YOLOv8.1.30 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (AMD EPYC 7B12)
# ...
